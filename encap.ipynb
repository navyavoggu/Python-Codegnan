# %%
class Bank:
    def __init__(self,username,password,amount):
         self.username = username #public attribute
         self._password = password #protected
         self.__amount =amount  #privite
    def withdraw(self,withdraw_amount):
        if self.__amount >= withdraw_amount:
            self.__amount -= withdraw_amount
            return f'withdraaw successful and current balance is{self.__amount}'
        else:
            return "Insufficient amount"
    def deposite(self,deposite_amount): #public method
        
            self.__amount += deposite_amount
            return f'deposite successful and current balance is{self.__amount}'
    def __total_users(self): #privite method
       return "Total users is 101"
#creating object for bank
b = Bank('Navya','Voggu',1000)
print(b.username)
print(b.deposite(100))
print(b.withdraw(10))
print(b._password)#protected member access
print(b._Bank__amount)#private member access using name mangling
print(b._Bank__total_users())#private method access using name mangling
# Out:
# Navya
# deposite successful and current balance is1100
# withdraaw successful and current balance is1090
# Voggu
# 1090
# Total users is 101
