# %% [markdown]
# ***EXCEPTION***

# %% [markdown]
# *****This is BUILT - IN Exception****

# %%
res = [10]
res = 0

# %%
if 1 > 0:
print(1)
# Out:
#   Cell In[1], line 2
#     print(1)
#     ^
# IndentationError: expected an indented block after 'if' statement on line 1

# %%
a = 10
b = 4
c = c + a
print(c)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 3
#       1 a = 10
#       2 b = 4
# ----> 3 c = c + a
#       4 print(c)
#
# NameError: name 'c' is not defined

# %%
a = 10 / 0
print(a)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 a = 10 / 0
#       2 print(a)
#
# ZeroDivisionError: division by zero

# %%
d = {1:'a',2:'b',3:'c'}
print(d[4])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 2
#       1 d = {1:'a',2:'b',3:'c'}
# ----> 2 print(d[4])
#
# KeyError: 4

# %%
s = 'codegnan'
print(s.index('z'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 2
#       1 s = 'codegnan'
# ----> 2 print(s.index('z'))
#
# ValueError: substring not found

# %%
s = 'codegnan'
print(s.index('z))
# Out:
#   Cell In[6], line 2
#     print(s.index('z))
#                   ^
# SyntaxError: unterminated string literal (detected at line 2)

# %% [markdown]
# **Exception Handling**

# %%
try:
    res = 10/0
    print(res)
except:
    print("Something wrong in code")
# Out:
# Something wrong in code

# %%
# Exception handling using Exception class
try:
    res = 10/0
    print(res)
except Exception as e:
    print("Something wrong in code:",e)
# Out:
# Something wrong in code: division by zero

# %%
#
try:
    res = 10
    print(res[0])
except Exception as e:
    print("Something wrong in code:",e)
# Out:
# Something wrong in code: 'int' object is not subscriptable

# %%
#Exception Handling 
# can't handle syntax error in try - except blocks
try:
    res = "string
    print(res[0])
except Exception as e:
    print("something wrong in code:",e)
# Out:
#   Cell In[18], line 4
#     res = "string
#           ^
# SyntaxError: unterminated string literal (detected at line 4)

# %%
#Exception Handling 
# can't handle syntax error in try - except blocks
try:
    res = "string"
    print(res[0])
    print(10/0)
    print(a)
except Exception as e:
    print("something wrong in code:",e)
# Out:
# s
# something wrong in code: division by zero

# %%
#Exception Handling 
# can't handle syntax error in try - except blocks
try:
    res = "string"
    print(res[0])
    print([1,2,3,4][0])
    print(z)
except TypeError:
    print("your performing the wrong operation with type data")
except ZeroDivisionError:
    print("Zero division not possiable")
except IndexError:
    print("Element not found at given index position")
except Exception as e:
    print("Something wrong in code:",e)
# Out:
# s
# 1
# Something wrong in code: name 'z' is not defined
